# %% [markdown]
# # SqueezeNet
#
# In this file we train the SqueezeNet model as described in the paper found [here](https://arxiv.org/abs/1602.07360).
# This implementation uses the CIFAR10 dataset.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.ao.quantization import QuantStub, DeQuantStub
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

from collections import OrderedDict

# %% [markdown]
# ## Implementation
#
# The class in this cell below defines our architecture and defines our forward pass. We insert quantization stub for later Quantization Aware Training. We also define helper functions to save and load the model.

# %%
import math
class Fire(nn.Module):
    def __init__(self, inplanes, squeeze_planes, expand_planes):
        super(Fire, self).__init__()
        self.conv1 = nn.Conv2d(inplanes, squeeze_planes, kernel_size=1)
        self.bn1 = nn.BatchNorm2d(squeeze_planes)
        self.relu1 = nn.ReLU(inplace=True)
        self.conv2 = nn.Conv2d(squeeze_planes, expand_planes, kernel_size=1)
        self.bn2 = nn.BatchNorm2d(expand_planes)
        self.conv3 = nn.Conv2d(squeeze_planes, expand_planes, kernel_size=3, padding=1)
        self.bn3 = nn.BatchNorm2d(expand_planes)
        self.relu2 = nn.ReLU(inplace=True)

        # MSR initialization
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.in_channels
                m.weight.data.normal_(0, math.sqrt(2. / n))

    def forward(self, x):
        x = self.relu1(self.bn1(self.conv1(x)))
        out1 = self.bn2(self.conv2(x))
        out2 = self.bn3(self.conv3(x))
        out = torch.cat([out1, out2], 1)
        out = self.relu2(out)
        return out

        # x = self.relu1(self.conv1(x))
        # out1 = self.conv2(x)
        # out2 = self.conv3(x)
        # out = torch.cat([out1, out2], 1)
        # out = self.relu2(out)
        # return out

class SqueezeNetCIFAR10(nn.Module):
    def __init__(self, num_classes=10):
        super(SqueezeNetCIFAR10, self).__init__()
        self.quant = QuantStub()
        self.dequant = DeQuantStub()

        self.conv1 = nn.Conv2d(3, 96, kernel_size=3, stride=1, padding=1)
        self.bn1 = nn.BatchNorm2d(96)
        self.relu = nn.ReLU(inplace=True)
        self.maxpool1 = nn.MaxPool2d(2, 2)  # 32 -> 16

        self.fire2 = Fire(96, 16, 64)
        self.fire3 = Fire(128, 16, 64)
        self.fire4 = Fire(128, 32, 128)
        self.maxpool2 = nn.MaxPool2d(2, 2)  # 16 -> 8

        self.fire5 = Fire(256, 32, 128)
        self.fire6 = Fire(256, 48, 192)
        self.fire7 = Fire(384, 48, 192)
        self.fire8 = Fire(384, 64, 256)
        self.maxpool3 = nn.MaxPool2d(2, 2)  # 8 -> 4

        self.fire9 = Fire(512, 64, 256)
        self.conv10 = nn.Conv2d(512, num_classes, kernel_size=1)
        self.avg_pool = nn.AvgPool2d(4)
        # self.softmax = nn.LogSoftmax(dim=1)

    def forward(self, x):
        x = self.quant(x)
        x = self.relu(self.bn1(self.conv1(x)))
        x = self.maxpool1(x)

        x = self.fire2(x)
        x = self.fire3(x)
        x = self.fire4(x)
        x = self.maxpool2(x)

        x = self.fire5(x)
        x = self.fire6(x)
        x = self.fire7(x)
        x = self.fire8(x)
        x = self.maxpool3(x)

        x = self.fire9(x)
        x = self.conv10(x)
        x = self.avg_pool(x)
        x = torch.flatten(x, 1)
        x = self.dequant(x)
        # x = self.softmax(x)
        return x
    
    def load_model(self, path='squeezenet_cifar10.pth',device='cpu'):
        state_dict = torch.load(path,map_location=device)

        new_state_dict = OrderedDict()
        for k, v in state_dict.items():
            if k.startswith('module.'):
                k = k[len('module.'):]
            new_state_dict[k] = v

        self.load_state_dict(new_state_dict)
        self.to(device)
        self.eval()

        print(f"Model loaded from {path}")
        # print(self)

    def save_model(self, path='squeezenet_cifar10.pth'):
        torch.save(self.state_dict(), path)
        print(f"Model saved to {path}")

# %% [markdown]
# ## Load the Dataset
#
# In this cell we define a function to load our dataset.

# %%
def load_dataset(path='./data', batch_size=64):
  print("Loading the CIFAR10 dataset")

  transform = transforms.Compose([
      transforms.ToTensor(), # scale RGB 0-255 to 0-1
      # normalize with known mean and std deviation of the CIFAR10 dataset
      transforms.Normalize((0.4914, 0.4822, 0.4465),(0.2023, 0.1994, 0.2010))
      ])

  # get training data
  train_dataset = datasets.CIFAR10(root=path, train=True, download=True, transform=transform)
  # get test data
  test_dataset = datasets.CIFAR10(root=path, train=False, download=True, transform=transform)
  # load the training data
  train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
  # load the test data
  test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

  print(f"Loaded train data: {len(train_loader.dataset)} total samples, {len(train_loader)} batches\n"
      f"Loaded test data: {len(test_loader.dataset)} total samples, {len(test_loader)} batches")

  return train_loader, test_loader

# %%
train_loader, test_loader = load_dataset()

# %% [markdown]
# ## Train the model
#
# In the cells below we define a function to visualize our training and train our model

# %%
import matplotlib.pyplot as plt

def plot_metrics(metrics):
  train_losses = metrics.get('train_loss',None)
  test_losses = metrics.get('test_loss',None)
  train_accs = metrics.get('train_acc',None)
  test_accs = metrics.get('test_acc',None)

  epochs = range(1, len(train_losses) + 1)

  plt.figure(figsize=(12, 5))

  # Loss Graph
  plt.subplot(1, 2, 1)
  if train_losses:
    plt.plot(epochs, train_losses, label='Train Loss', marker='o')
  if test_losses:
    plt.plot(epochs, test_losses, label='Test Loss', marker='s')
  plt.xlabel('Epoch')
  plt.ylabel('Loss')
  plt.title('Training vs Test Loss')
  plt.legend()
  plt.grid(True, linestyle='--', alpha=0.6)

  # Accuracy Graph
  plt.subplot(1, 2, 2)
  if train_accs:
    plt.plot(epochs, train_accs, label='Train Accuracy', marker='o')
  if test_accs:
    plt.plot(epochs, test_accs, label='Test Accuracy', marker='s')
  plt.xlabel('Epoch')
  plt.ylabel('Accuracy (%)')
  plt.title('Training vs Test Accuracy')
  plt.legend()
  plt.grid(True, linestyle='--', alpha=0.6)

  plt.tight_layout()
  plt.show()

# %%
def train_model(model,train_loader,test_loader,train=True,test=True,device='cpu',epochs=10,lr=1e-3):
  model.to(device)
  metrics = {
        "train_loss": [],
        "train_acc": [],
        "test_loss": [],
        "test_acc": []
    }

  # TRAINING LOOP
  criterion = nn.CrossEntropyLoss()
  optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=1e-4)

  for e in range(epochs):
    print(f"Epoch [{e+1}/{epochs}] ",end='')
    if train:
      model.train()
      train_loss, total_examples, correct = 0.0, 0, 0

      for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad() # zero gradients
        outputs = model(inputs) # forward pass
        loss = criterion(outputs,labels) # get loss from cost function
        loss.backward() # backward propagation
        optimizer.step() # update gradients

        # train_loss += loss.item() # track total loss up to this point
        train_loss += loss.item() * labels.size(0)
        _, pred_ind = outputs.max(1) # get index of prediction (highest value)
        total_examples += labels.size(0) # update count for this epoch with batch size
        correct += pred_ind.eq(labels).sum().item() # return count of correct predictions

    #   train_loss /= len(train_loader) # get average per batch
      train_loss /= total_examples # get average per example
      train_acc = 100.0 * correct / total_examples

      metrics["train_loss"].append(train_loss)
      metrics["train_acc"].append(train_acc)

      print(f"Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.2f}% ",end='')

      # VALIDATION/TEST
    if test:
      model.eval()
      test_loss, total_examples, correct = 0.0, 0, 0

      with torch.no_grad():
        for inputs, labels in test_loader:
          inputs, labels = inputs.to(device), labels.to(device)
          outputs = model(inputs) # forward pass
          loss = criterion(outputs,labels) # get loss from cost function
          test_loss += loss.item() # update loss
          _, pred_ind = outputs.max(1) # get index of prediction (highest value)
          total_examples += labels.size(0) # update count for this epoch with batch size
          correct += pred_ind.eq(labels).sum().item() # return count of correct predictions

      test_loss /= len(test_loader)
      test_acc = 100.0 * correct / total_examples

      metrics["test_loss"].append(test_loss)
      metrics["test_acc"].append(test_acc)

      print(f"Test/Val Loss: {test_loss:.4f}, Test/Val Acc: {test_acc:.2f}%")

  return metrics

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device={device}")

model_fp32 = SqueezeNetCIFAR10()
# model_fp32 = SqueezeNet()

# model_fp32.load_model('squeezenet_cifar10_fp32.pth')
# Out:
# Device=cuda

# %%
train, test = True, True
epochs = 100
fp32_metrics = train_model(model=model_fp32,train_loader=train_loader,test_loader=test_loader,train=train,test=test,device=device,epochs=epochs)

# %%
model_fp32.save_model("squeezenet_cifar10_fp32.pth")

# %%
plot_metrics(fp32_metrics)

# %%
train, test = True, True
epochs = 100
fp32_metrics = train_model(model=model_fp32,train_loader=train_loader,test_loader=test_loader,train=train,test=test,device=device,epochs=epochs)
# Out:
# Epoch [1/100]
# Train Loss: 1.3658, Train Acc: 49.77%
# Test/Val Loss: 1.2860, Test/Val Acc: 56.07%
# Epoch [2/100]
# Train Loss: 0.9703, Train Acc: 65.44%
# Test/Val Loss: 0.9378, Test/Val Acc: 66.47%
# Epoch [3/100]
# Train Loss: 0.7917, Train Acc: 72.06%
# Test/Val Loss: 0.9349, Test/Val Acc: 67.96%
# Epoch [4/100]
# Train Loss: 0.6772, Train Acc: 76.19%
# Test/Val Loss: 0.8766, Test/Val Acc: 70.23%
# Epoch [5/100]
# Train Loss: 0.5956, Train Acc: 79.37%
# Test/Val Loss: 0.7614, Test/Val Acc: 74.69%
# Epoch [6/100]
# Train Loss: 0.5298, Train Acc: 81.51%
# Test/Val Loss: 0.6771, Test/Val Acc: 76.64%
# Epoch [7/100]
# Train Loss: 0.4777, Train Acc: 83.44%
# Test/Val Loss: 0.7464, Test/Val Acc: 75.76%
# Epoch [8/100]
# Train Loss: 0.4233, Train Acc: 85.34%
# Test/Val Loss: 0.7019, Test/Val Acc: 77.01%
# Epoch [9/100]
# Train Loss: 0.3824, Train Acc: 86.61%
# Test/Val Loss: 0.7068, Test/Val Acc: 76.84%
# Epoch [10/100]
# Train Loss: 0.3506, Train Acc: 87.78%
# Test/Val Loss: 0.7113, Test/Val Acc: 77.23%
# Epoch [11/100]
# Train Loss: 0.3136, Train Acc: 88.89%
# Test/Val Loss: 0.6807, Test/Val Acc: 78.42%
# Epoch [12/100]
# Train Loss: 0.2878, Train Acc: 89.93%
# Test/Val Loss: 0.7017, Test/Val Acc: 78.74%
# Epoch [13/100]
# Train Loss: 0.2616, Train Acc: 90.82%
# Test/Val Loss: 0.6854, Test/Val Acc: 79.48%
# Epoch [14/100]
# Train Loss: 0.2386, Train Acc: 91.58%
# Test/Val Loss: 0.7640, Test/Val Acc: 77.42%
# Epoch [15/100]
# Train Loss: 0.2237, Train Acc: 91.94%
# Test/Val Loss: 0.7277, Test/Val Acc: 79.23%
# Epoch [16/100]
# Train Loss: 0.2063, Train Acc: 92.75%
# Test/Val Loss: 0.7007, Test/Val Acc: 80.13%
# Epoch [17/100]
# Train Loss: 0.1944, Train Acc: 93.11%
# Test/Val Loss: 0.7140, Test/Val Acc: 80.12%
# Epoch [18/100]
# Train Loss: 0.1894, Train Acc: 93.31%
# Test/Val Loss: 0.8063, Test/Val Acc: 78.45%
# Epoch [19/100]
# Train Loss: 0.1734, Train Acc: 93.79%
# Test/Val Loss: 0.7239, Test/Val Acc: 79.73%
# Epoch [20/100]
# Train Loss: 0.1670, Train Acc: 94.03%
# Test/Val Loss: 0.7711, Test/Val Acc: 79.49%
# Epoch [21/100]
# Train Loss: 0.1542, Train Acc: 94.54%
# Test/Val Loss: 0.9746, Test/Val Acc: 76.39%
# Epoch [22/100]
# Train Loss: 0.1540, Train Acc: 94.58%
# Test/Val Loss: 0.7310, Test/Val Acc: 80.17%
# Epoch [23/100]
# Train Loss: 0.1512, Train Acc: 94.67%
# Test/Val Loss: 0.7376, Test/Val Acc: 80.67%
# Epoch [24/100]
# Train Loss: 0.1442, Train Acc: 94.94%
# Test/Val Loss: 0.7855, Test/Val Acc: 79.53%
# Epoch [25/100]
# Train Loss: 0.1413, Train Acc: 95.10%
# Test/Val Loss: 0.7798, Test/Val Acc: 79.81%
# Epoch [26/100]
# Train Loss: 0.1324, Train Acc: 95.32%
# Test/Val Loss: 0.8179, Test/Val Acc: 79.65%
# Epoch [27/100]
# Train Loss: 0.1333, Train Acc: 95.30%
# Test/Val Loss: 0.7968, Test/Val Acc: 79.70%
# Epoch [28/100]
# Train Loss: 0.1279, Train Acc: 95.49%
# Test/Val Loss: 0.8551, Test/Val Acc: 78.24%
# Epoch [29/100]
# Train Loss: 0.1337, Train Acc: 95.30%
# Test/Val Loss: 0.8005, Test/Val Acc: 79.33%
# Epoch [30/100]
# Train Loss: 0.1234, Train Acc: 95.62%
# Test/Val Loss: 0.8019, Test/Val Acc: 79.83%
# Epoch [31/100]
# Train Loss: 0.1198, Train Acc: 95.80%
# Test/Val Loss: 0.7517, Test/Val Acc: 80.61%
# Epoch [32/100]
# Train Loss: 0.1257, Train Acc: 95.64%
# Test/Val Loss: 0.7643, Test/Val Acc: 80.61%
# Epoch [33/100]
# Train Loss: 0.1183, Train Acc: 95.93%
# Test/Val Loss: 0.8820, Test/Val Acc: 78.99%
# Epoch [34/100]
# Train Loss: 0.1144, Train Acc: 96.12%
# Test/Val Loss: 0.7971, Test/Val Acc: 80.27%
# Epoch [35/100]
# Train Loss: 0.1266, Train Acc: 95.51%
# Test/Val Loss: 0.7905, Test/Val Acc: 80.05%
# Epoch [36/100]
# Train Loss: 0.1148, Train Acc: 95.98%
# Test/Val Loss: 0.7453, Test/Val Acc: 81.32%
# Epoch [37/100]
# Train Loss: 0.1107, Train Acc: 96.04%
# Test/Val Loss: 0.8094, Test/Val Acc: 79.68%
# Epoch [38/100]
# Train Loss: 0.1121, Train Acc: 96.11%
# Test/Val Loss: 0.8312, Test/Val Acc: 79.16%
# Epoch [39/100]
# Train Loss: 0.1089, Train Acc: 96.18%
# Test/Val Loss: 0.8076, Test/Val Acc: 79.96%
# Epoch [40/100]
# Train Loss: 0.1089, Train Acc: 96.11%
# Test/Val Loss: 0.8269, Test/Val Acc: 79.55%
# Epoch [41/100]
# Train Loss: 0.1051, Train Acc: 96.30%
# Test/Val Loss: 0.8100, Test/Val Acc: 79.12%
# Epoch [42/100]
# Train Loss: 0.1118, Train Acc: 95.97%
# Test/Val Loss: 0.8448, Test/Val Acc: 79.49%
# Epoch [43/100]
# Train Loss: 0.1056, Train Acc: 96.27%
# Test/Val Loss: 0.8344, Test/Val Acc: 80.06%
# Epoch [44/100]
# Train Loss: 0.1059, Train Acc: 96.35%
# Test/Val Loss: 0.9013, Test/Val Acc: 79.39%
# Epoch [45/100]
# Train Loss: 0.1008, Train Acc: 96.47%
# Test/Val Loss: 0.8064, Test/Val Acc: 80.37%
# Epoch [46/100]
# Train Loss: 0.1063, Train Acc: 96.21%
# Test/Val Loss: 0.8612, Test/Val Acc: 79.34%
# Epoch [47/100]
# Train Loss: 0.1008, Train Acc: 96.47%
# Test/Val Loss: 0.8211, Test/Val Acc: 80.55%
# Epoch [48/100]
# Train Loss: 0.1098, Train Acc: 96.16%
# Test/Val Loss: 0.7715, Test/Val Acc: 80.54%
# Epoch [49/100]
# Train Loss: 0.0971, Train Acc: 96.66%
# Test/Val Loss: 0.7719, Test/Val Acc: 81.27%
# Epoch [50/100]
# Train Loss: 0.1052, Train Acc: 96.24%
# Test/Val Loss: 0.7523, Test/Val Acc: 81.29%
# Epoch [51/100]
# Train Loss: 0.0977, Train Acc: 96.62%
# Test/Val Loss: 0.8149, Test/Val Acc: 80.24%
# Epoch [52/100]
# Train Loss: 0.0970, Train Acc: 96.59%
# Test/Val Loss: 0.8618, Test/Val Acc: 79.85%
# Epoch [53/100]
# Train Loss: 0.1108, Train Acc: 96.12%
# Test/Val Loss: 0.7854, Test/Val Acc: 80.53%
# Epoch [54/100]
# Train Loss: 0.0932, Train Acc: 96.78%
# Test/Val Loss: 0.8014, Test/Val Acc: 80.56%
# Epoch [55/100]
# Train Loss: 0.1010, Train Acc: 96.51%
# Test/Val Loss: 0.8889, Test/Val Acc: 79.15%
# Epoch [56/100]
# Train Loss: 0.0927, Train Acc: 96.67%
# Test/Val Loss: 0.7693, Test/Val Acc: 81.31%
# Epoch [57/100]
# Train Loss: 0.0985, Train Acc: 96.50%
# Test/Val Loss: 0.7918, Test/Val Acc: 80.97%
# Epoch [58/100]
# Train Loss: 0.0937, Train Acc: 96.82%
# Test/Val Loss: 0.9410, Test/Val Acc: 78.33%
# Epoch [59/100]
# Train Loss: 0.0961, Train Acc: 96.66%
# Test/Val Loss: 0.7938, Test/Val Acc: 80.89%
# Epoch [60/100]
# Train Loss: 0.0932, Train Acc: 96.68%
# Test/Val Loss: 0.8521, Test/Val Acc: 79.85%
# Epoch [61/100]
# Train Loss: 0.0975, Train Acc: 96.63%
# Test/Val Loss: 0.8566, Test/Val Acc: 79.54%
# Epoch [62/100]
# Train Loss: 0.0889, Train Acc: 96.84%
# Test/Val Loss: 0.8921, Test/Val Acc: 79.36%
# Epoch [63/100]
# Train Loss: 0.1010, Train Acc: 96.44%
# Test/Val Loss: 0.8390, Test/Val Acc: 79.95%
# Epoch [64/100]
# Train Loss: 0.0915, Train Acc: 96.85%
# Test/Val Loss: 0.7704, Test/Val Acc: 80.63%
# Epoch [65/100]
# Train Loss: 0.0911, Train Acc: 96.80%
# Test/Val Loss: 0.8776, Test/Val Acc: 78.86%
# Epoch [66/100]
# Train Loss: 0.0894, Train Acc: 96.96%
# Test/Val Loss: 0.7501, Test/Val Acc: 81.37%
# Epoch [67/100]
# Train Loss: 0.0909, Train Acc: 96.84%
# Test/Val Loss: 0.8926, Test/Val Acc: 79.92%
# Epoch [68/100]
# Train Loss: 0.0916, Train Acc: 96.79%
# Test/Val Loss: 0.8028, Test/Val Acc: 80.81%
# Epoch [69/100]
# Train Loss: 0.0915, Train Acc: 96.83%
# Test/Val Loss: 0.8829, Test/Val Acc: 79.32%
# Epoch [70/100]
# Train Loss: 0.0942, Train Acc: 96.76%
# Test/Val Loss: 0.7845, Test/Val Acc: 81.29%
# Epoch [71/100]
# Train Loss: 0.0862, Train Acc: 96.92%
# Test/Val Loss: 1.0333, Test/Val Acc: 77.33%
# Epoch [72/100]
# Train Loss: 0.0883, Train Acc: 96.95%
# Test/Val Loss: 0.8001, Test/Val Acc: 80.45%
# Epoch [73/100]
# Train Loss: 0.0892, Train Acc: 96.85%
# Test/Val Loss: 0.8538, Test/Val Acc: 80.05%
# Epoch [74/100]
# Train Loss: 0.0904, Train Acc: 96.76%
# Test/Val Loss: 0.8423, Test/Val Acc: 80.46%
# Epoch [75/100]
# Train Loss: 0.0860, Train Acc: 97.04%
# Test/Val Loss: 0.8218, Test/Val Acc: 80.64%
# Epoch [76/100]
# Train Loss: 0.0856, Train Acc: 97.02%
# Test/Val Loss: 0.8228, Test/Val Acc: 80.39%
# Epoch [77/100]
# Train Loss: 0.0919, Train Acc: 96.81%
# Test/Val Loss: 0.7879, Test/Val Acc: 81.09%
# Epoch [78/100]
# Train Loss: 0.0939, Train Acc: 96.78%
# Test/Val Loss: 0.7830, Test/Val Acc: 80.86%
# Epoch [79/100]
# Train Loss: 0.0822, Train Acc: 97.15%
# Test/Val Loss: 0.8316, Test/Val Acc: 81.01%
# Epoch [80/100]
# Train Loss: 0.0949, Train Acc: 96.76%
# Test/Val Loss: 0.8085, Test/Val Acc: 80.42%
# Epoch [81/100]
# Train Loss: 0.0819, Train Acc: 97.18%
# Test/Val Loss: 0.7882, Test/Val Acc: 80.95%
# Epoch [82/100]
# Train Loss: 0.0911, Train Acc: 96.91%
# Test/Val Loss: 0.7579, Test/Val Acc: 81.73%
# Epoch [83/100]
# Train Loss: 0.0840, Train Acc: 97.08%
# Test/Val Loss: 0.7990, Test/Val Acc: 80.73%
# Epoch [84/100]
# Train Loss: 0.0965, Train Acc: 96.62%
# Test/Val Loss: 0.7484, Test/Val Acc: 81.94%
# Epoch [85/100]
# Train Loss: 0.0836, Train Acc: 97.15%
# Test/Val Loss: 0.7625, Test/Val Acc: 81.40%
# Epoch [86/100]
# Train Loss: 0.0850, Train Acc: 97.00%
# Test/Val Loss: 0.7770, Test/Val Acc: 81.95%
# Epoch [87/100]
# Train Loss: 0.0831, Train Acc: 97.13%
# Test/Val Loss: 0.7916, Test/Val Acc: 81.04%
# Epoch [88/100]
# Train Loss: 0.0872, Train Acc: 96.95%
# Test/Val Loss: 0.7862, Test/Val Acc: 81.20%
# Epoch [89/100]
# Train Loss: 0.0886, Train Acc: 96.84%
# Test/Val Loss: 0.7841, Test/Val Acc: 81.08%
# Epoch [90/100]
# Train Loss: 0.0862, Train Acc: 96.91%
# Test/Val Loss: 0.7305, Test/Val Acc: 82.24%
# Epoch [91/100]
# Train Loss: 0.0822, Train Acc: 97.13%
# Test/Val Loss: 0.7898, Test/Val Acc: 81.06%
# Epoch [92/100]
# Train Loss: 0.0871, Train Acc: 97.01%
# Test/Val Loss: 0.7897, Test/Val Acc: 80.85%
# Epoch [93/100]
# Train Loss: 0.0909, Train Acc: 96.76%
# Test/Val Loss: 0.8379, Test/Val Acc: 80.69%
# Epoch [94/100]
# Train Loss: 0.0800, Train Acc: 97.21%
# Test/Val Loss: 0.8299, Test/Val Acc: 81.01%
# Epoch [95/100]
# Train Loss: 0.0852, Train Acc: 97.01%
# Test/Val Loss: 0.7415, Test/Val Acc: 82.51%
# Epoch [96/100]
# Train Loss: 0.0869, Train Acc: 96.98%
# Test/Val Loss: 0.8063, Test/Val Acc: 80.44%
# Epoch [97/100]
# Train Loss: 0.0783, Train Acc: 97.32%
# Test/Val Loss: 0.7582, Test/Val Acc: 81.24%
# Epoch [98/100]
# Train Loss: 0.0867, Train Acc: 97.00%
# Test/Val Loss: 0.8081, Test/Val Acc: 81.13%
# Epoch [99/100]
# Train Loss: 0.0860, Train Acc: 97.04%
# Test/Val Loss: 0.7913, Test/Val Acc: 81.53%
# Epoch [100/100]
# Train Loss: 0.0758, Train Acc: 97.39%
# Test/Val Loss: 0.8656, Test/Val Acc: 80.68%

# %%
model_fp32.save_model("squeezenet_bn_cifar10_fp32.pth")
# Out:
# Model saved to squeezenet_bn_cifar10_fp32.pth

# %%
plot_metrics(fp32_metrics)
